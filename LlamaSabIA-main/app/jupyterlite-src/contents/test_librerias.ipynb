# %% [markdown]
# # Test de librerías científicas y de IA
# Este notebook verifica que todas las librerías necesarias están instaladas y funcionando en el entorno offline embebido.

# %%
# Importar librerías estándar y científicas
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
print('Todas las librerías se importaron correctamente.')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       2 import os
#       3 import random
# ----> 4 import numpy as np
#       5 import matplotlib.pyplot as plt
#       6 from sklearn.metrics import confusion_matrix, classification_report
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# Prueba rápida de numpy y matplotlib
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title('Seno usando numpy y matplotlib')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Prueba rápida de numpy y matplotlib
# ----> 2 x = np.linspace(0, 2 * np.pi, 100)
#       3 y = np.sin(x)
#       4 plt.plot(x, y)
#
# NameError: name 'np' is not defined

# %%
# Prueba rápida de sklearn
y_true = [0, 1, 2, 2, 0]
y_pred = [0, 0, 2, 2, 0]
print('Confusion matrix:')
print(confusion_matrix(y_true, y_pred))
print('Classification report:')
print(classification_report(y_true, y_pred))

# %%
# Prueba rápida de TensorFlow y Keras
model = keras.Sequential([
    layers.Dense(10, activation='relu', input_shape=(5,)),
    layers.Dense(1, activation='sigmoid')
])
model.summary()
